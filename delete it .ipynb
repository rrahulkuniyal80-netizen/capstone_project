# %%
df = pd.read_csv('data_viz.xls')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.3 MB 2.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.3 MB 2.2 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/9.3 MB 2.2 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.3 MB 2.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.4/9.3 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.6/9.3 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/9.3 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/9.3 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/9.3 MB 1.9 MB/s eta 0:00:04
# ...

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rapidfuzz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
# ...
